# %% [markdown]
# # Stem-and-leaf with R
#
# `stem` from R -- a statistical language and toolset -- is the easiest tool to use to create stem-and-leaf plots

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# stem(c(1, 3, 5, 10, 17, 17))

# %% [markdown]
# # Stem-and-leaf with Python

# %% [markdown]
# ## Stem-and-leaf with `stemgraphic`

# %%
# !pip install -q stemgraphic

# %%
import stemgraphic as sg

# %%
sg.stem_graphic([1, 3, 5, 10, 17, 17], compact=True)

# %% [markdown]
# Same using a Pandas dataframe

# %%
import pandas as pd
df = pd.Series([1, 3, 5, 10, 17, 17])
sg.stem_graphic(df, compact=True, asc=False)

# %% [markdown]
# ## Matplotlib stem plot
#
# `stem` plots vertical lines from a baseline to the y-coordinate and places a marker at the tip.

# %%
import matplotlib.pyplot as plt
plt.stem([1, 3, 5, 10, 17, 17])

# %% [markdown]
# Setting the figure size

# %%
plt.rcParams["figure.figsize"] = (2,5)
plt.stem([1, 3, 5, 10, 17, 17])

# %% [markdown]
# # Exercises

# %% [markdown]
# ## 😜 Exercise 1
#
# Use R `stem` to create a stem-and-leaf plot of the cholesterol level in `heart-decease.cleveland.csv`.
#
# __Hints:__
#
# - `HEART-DECEASE-README.md` contains the data dictionary
# - Use `read.csv` to load the data in a dataframe
# - Use `df$chol` to access the chol column once loaded in a dataframe

# %% [markdown]
# ## 😜 Exercise 2
#
# Use `stem_graphic` to create a stem-and-leaf plot of the cholesterol level in `heart-decease.cleveland.csv`.
#
# Customize the plot adding a title, display the units as `mg/dl` and list values in descending order.
#
# Hints:
# - Use pandas to load the data in a dataframe
# - Use df.chol to access the chol column once loaded in the dataframe
# - Use `asc=False, unit="mg/dl", title="Cleveland dataset"` to customize

# %% [markdown]
# ## 😜 Exercise 3
#
# Use matplotlib `stem` to create a stem-and-leaf plot of the cholesterol level in `heart-decease.cleveland.csv`.
